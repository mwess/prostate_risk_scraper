# %%
import pandas as pd

# %%
df = pd.read_excel('Biopsied patients_relevant_columns_imputed_DRE_and_fam_hist.xlsx')
df
# Out:
#                Sheet_ID  age   PSA2  prostatevolume R_roentgendiagnose  \
# 0    DLR_0160_PF_141019   57   8.40            31.0            PIRADS2
# 1    DLR_0190_PF_090321   74  26.70            57.0            PIRADS2
# 2    DLR_0291_PF_310122   65   8.11            80.0            PIRADS5
# 3    DLR_0325_PF_021221   64   8.67            67.6            PIRADS2
# 4    DLR_0472_PF_280921   75   8.97            83.0            PIRADS2
# ..                  ...  ...    ...             ...                ...
# 417  DLR_2558_PF_220222   70   7.47            36.0            PIRADS4
# 418  DLR_2561_PF_230222   76   9.10            36.0            PIRADS4
# 419  DLR_2562_PF_280222   54   7.10            25.0            PIRADS4
# 420  DLR_2565_PF_010322   67  19.00            40.0            PIRADS4
# 421  DLR_2569_PF_020322   68   2.47            28.0            PIRADS5
#
#                     Type_biopsi  \
# 0              systematisk TRUS
# 1              systematisk TRUS
# ...
